# %% [markdown]
# # Day 11 - Creative Function Exercises: Student Version
#
# ชุดโจทย์เสริมเรื่อง `function` เรียงจากง่ายไปยาก สำหรับนักเรียน
#
# วิธีใช้:
#
# 1. อ่านโจทย์
# 2. เติม code ใน cell ที่มี `TODO`
# 3. แทนที่ `...` ด้วยคำตอบของตัวเอง
# 4. รัน cell และทดลองเปลี่ยน argument

# %% [markdown]
# ## Level 1: Quest Welcome Sign
#
# สร้าง `show_quest_welcome()` ที่ไม่มีพารามิเตอร์ และแสดงข้อความสองบรรทัด:
#
# ```text
# Welcome, adventurer!
# Your quest begins now.
# ```

# %%
# Level 1: TODO
def show_quest_welcome():
    print("Welcome, adventurer!")
    print("Your quest begins now.")

show_quest_welcome()
# Out:
# Welcome, adventurer!
# Your quest begins now.

# %% [markdown]
# ## Level 2: Player Tag Generator
#
# สร้าง `create_player_tag(name, role)` ที่คืนข้อความรูปแบบ `[Mage] Luna` แล้วเก็บค่าที่ return ในตัวแปร

# %%
def test(a,b):
    return a,b
test_function = test(1,4)
print(test_function)
# Out:
# (1, 4)

# %%
# Level 2: TODO
def create_player_tag(name, role):
    return f"[{role}] {name}"


player_tag = create_player_tag('Luna', 'Mage')
print(player_tag)
# Out:
# [Mage] Luna

# %% [markdown]
# ## Level 3: Potion Mixer
#
# สร้าง `mix_potion(red, blue)` ที่คืนจำนวนขวดทั้งหมด ทดสอบด้วย `(3, 5)` ซึ่งควรได้ `8`

# %%
# Level 3: TODO
def mix_potion(red, blue):
    return red + blue


print(mix_potion(123, 5))
# Out:
# 128

# %% [markdown]
# ## Level 4: Spaceship Boarding Pass
#
# สร้าง `boarding_pass(name, planet, seat)` ที่คืนข้อความข้อมูลผู้โดยสาร แล้วเรียกด้วย keyword arguments แบบสลับลำดับ
#
# ### ตัวอย่าง Output
#
# ```text
# Passenger: Mina | Destination: Mars | Seat: A7
# ```

# %%
# Level 4: TODO
def boarding_pass(name, planet, seat):
    return f"Passenger: {name} | Destination: {planet} | Seat: {seat}"


ticket = boarding_pass(planet="Mars", name="Mina" , seat="B8")
print(ticket)
# Out:
# Passenger: Mina | Destination: Mars | Seat: B8

# %% [markdown]
# ## Level 5: Planet Weight Calculator
#
# สร้าง `calculate_weight(mass, gravity=9.81)` ให้คืน `mass × gravity`
#
# ทดสอบน้ำหนักบนโลกและดวงจันทร์ซึ่งมี gravity `1.62`

# %%
# Level 5: TODO
def calculate_weight(mass, gravity=9.81):
    return mass*gravity


print('Earth:', calculate_weight(50))
print('Moon:', calculate_weight(50, gravity=1.62))
# Out:
# Earth: 490.5
# Moon: 81.0

# %% [markdown]
# ## Level 6: Party Score Collector
#
# สร้าง `total_party_score(*scores)` ที่รับคะแนนได้ไม่จำกัดจำนวนและคืนผลรวม
#
# ทดสอบทั้งแบบไม่มีคะแนนและมีหลายคะแนน

# %%
def test(*a):
    print(a)

test(1,2,3,4,5,6,7,8)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
# Level 6: TODO
def total_party_score(*scores):
    return sum(scores)


# print(total_party_score())
print(total_party_score(120, 85, 200, 95,45,3,2,5,6,4,2,235,6,3))
# Out:
# 811

# %% [markdown]
# ## Level 7: Character Card Builder
#
# สร้าง `build_character(name, **stats)` ที่คืน dictionary ซึ่งรวม `name` กับข้อมูลทั้งหมดจาก `stats`
#
# ### ตัวอย่าง Output
#
# ```text
# {'name': 'Luna', 'role': 'Mage', 'level': 8, 'hp': 90, 'mana': 150}
# ```

# %%
def test(**a):
    print(a)

test(a=1,b=2,c=3,d =4)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
a = {"name" : "abc"}
a["surname"] = "efg"

print(a)
# Out:
# {'name': 'abc', 'surname': 'efg'}

# %%
a = {"test": 3}

b = {"test1": 4, "test2": 5}

a.update(b)

print(a)
# Out:
# {'test': 3, 'test1': 4, 'test2': 5}

# %%
# Level 7: TODO
def build_character(name, **stats):
    character = {"name" : name}
    # print("stat" ,stats)
    character.update(stats)
    if len(character) > 4:
        return character
        # return
    else:
        return False

luna = build_character('Luna', role='Mage', level=8, hp=90, mana=150)
print(luna) # {'name' : 'Luna'}
# Out:
# {'name': 'Luna', 'role': 'Mage', 'level': 8, 'hp': 90, 'mana': 150}

# %% [markdown]
# ## Level 8: Dictionary Teleporter
#
# สร้าง `teleport(name, location, energy)` แล้วเรียกด้วย dictionary unpacking (`**`) จาก `teleport_data`
#
# ### ตัวอย่าง Output
#
# ```text
# Kai teleported to Crystal Cave using 25 energy.
# ```

# %%
# Level 8: TODO
def teleport(name, location, energy):
    return f"{name} teleport to {location} using {energy}."


teleport_data = {
    'name': 'Peem',
    'location': 'Crystal Cave',
    'energy': 25,
}

print(teleport(**teleport_data))
# Out:
# Peem teleport to Crystal Cave using 25.

# %%
def test(a,b,c):
    return a+b

test_a = {
    "a" : 1,
    "b" : 2,
    "c" : 3,
}

print(test(**test_a))
print(test(test_a["a"], test_a["b"],test_a["c"]))
# Out:
# 3
# 3

# %% [markdown]
# ## Level 9: Power-Up Machine
#
# สร้าง `double_power`, `square_power` และ `apply_power_up(value, power_function)` ซึ่งเรียกฟังก์ชันที่รับเข้ามา

# %%
# Level 9: TODO
def double_power(value):
    return value * 2

def square_power(value):
    return value **2

def apply_power_up(value, power_function):
    return power_function(value)


print(apply_power_up(5, double_power))
print(apply_power_up(5, square_power))

print(double_power(30))
print(square_power(12))
# Out:
# 10
# 25
# 60
# 144

# %% [markdown]
# ## Level 10: Boss Battle Check
#
# สร้าง `is_ready_for_boss(level, potions)` ให้คืน boolean ผู้เล่นพร้อมเมื่อ level ≥ 10 และ potion ≥ 3

# %%
print(7 > 5 and 1>2)
# Out:
# False

# %%
# Level 10: TODO
def is_ready_for_boss(level, potions):
    return level >= 10 and potions >= 3

print(is_ready_for_boss(12, 4))
print(is_ready_for_boss(9, 5))
# Out:
# True
# False

# %% [markdown]
# ## Level 11: Rare Loot Filter
#
# สร้าง `find_rare_loot(items, minimum_rarity=4)` ให้คืน list ชื่อ item ที่มี `rarity` ถึงเกณฑ์

# %%
# Level 11: TODO
def find_rare_loot(items, minimum_rarity=4):
    ...


loot = [
    {'name': 'Wooden Sword', 'rarity': 1},
    {'name': 'Dragon Shield', 'rarity': 5},
    {'name': 'Crystal Ring', 'rarity': 4},
]

print(find_rare_loot(loot))

# %% [markdown]
# ## Level 12: Temperature Station
#
# สร้าง `celsius_to_fahrenheit(celsius)` และ `convert_temperatures(values)`
#
# ฟังก์ชันที่สองต้องเรียกฟังก์ชันแรก ห้ามเขียนสูตรซ้ำ

# %%
# Level 12: TODO
def celsius_to_fahrenheit(celsius):
    ...

def convert_temperatures(values):
    ...


print(convert_temperatures([0, 20, 37, 100]))

# %% [markdown]
# ## Level 13: Battle Report
#
# สร้าง `battle_report(damage_values)` ให้คืน dictionary ที่มี `total_damage`, `highest_damage`, `average_damage` และ `hit_count`

# %%
# Level 13: TODO
def battle_report(damage_values):
    ...


print(battle_report([12, 30, 18, 40]))

# %% [markdown]
# ## Level 14: Hero Name Pipeline
#
# สร้าง `clean_name`, `capitalize_name`, `add_title` และ `format_hero_name` เพื่อเปลี่ยน `'  luna moon  '` เป็น `'Hero Luna Moon'`

# %%
# Level 14: TODO
def clean_name(name):
    ...

def capitalize_name(name):
    ...

def add_title(name):
    ...

def format_hero_name(name):
    # TODO: เรียกฟังก์ชันย่อยตามลำดับ
    ...


print(format_hero_name('  luna moon  '))

# %% [markdown]
# ## Level 15: Leaderboard Toolkit
#
# สร้าง `tournament_score(player)` จากสูตร `wins × 3 + assists` และ `rank_players(players, score_function)` ให้คืนรายชื่อเรียงคะแนนสูงไปต่ำ

# %%
# Level 15: TODO
def tournament_score(player):
    ...

def rank_players(players, score_function):
    ...


players = [
    {'name': 'Mina', 'wins': 4, 'assists': 3},
    {'name': 'Leo', 'wins': 3, 'assists': 8},
    {'name': 'Kai', 'wins': 5, 'assists': 1},
]

print(rank_players(players, tournament_score))

# %% [markdown]
# ## Level 16: Magic Dice Arena
#
# สร้าง `calculate_dice_attack(*rolls, bonus=0, critical=False)`
#
# รวมแต้มลูกเต๋ากับ bonus ถ้าเป็น critical ให้คูณสอง แล้วคืน dictionary ที่มี `rolls`, `bonus`, `critical` และ `damage`

# %%
# Level 16: TODO
def calculate_dice_attack(*rolls, bonus=0, critical=False):
    ...


print(calculate_dice_attack(4, 6, 3, bonus=2))
print(calculate_dice_attack(6, 6, bonus=3, critical=True))

# %% [markdown]
# ## Level 17: Robot Command Composer
#
# สร้าง `program_robot(robot, *actions, separator=' -> ', **settings)` ให้คืน dictionary ที่มีชื่อหุ่นยนต์ คำสั่งที่ต่อกัน และ settings ทั้งหมด

# %%
# Level 17: TODO
def program_robot(robot, *actions, separator=' -> ', **settings):
    ...


mission = program_robot(
    'RX-7', 'scan', 'move north', 'collect crystal', 'return',
    speed='turbo', voice='friendly'
)
print(mission)

# %% [markdown]
# ## Level 18: Spell Factory
#
# สร้าง `create_spell(element, multiplier)` ซึ่งคืนฟังก์ชัน `cast(base_power)`
#
# เช่น เวทไฟ multiplier `3` และ base power `12` ต้องสร้างความเสียหาย `36`

# %%
# Level 18: TODO
def create_spell(element, multiplier):
    # TODO: สร้างฟังก์ชัน cast ภายในและ return ออกมา
    ...


fire_spell = create_spell('fire', 3)
ice_spell = create_spell('ice', 2)

# ยกเลิก comment หลังจากเขียนฟังก์ชันเสร็จ
# print(fire_spell(12))
# print(ice_spell(10))

# %% [markdown]
# ## Level 19: Quest Validation Council
#
# สร้างกฎ `has_enough_level`, `has_magic_key`, `has_full_health`
#
# จากนั้นสร้าง `check_quest_access(player, *rules)` ให้เรียกทุกกฎและคืนชื่อกฎที่ไม่ผ่าน

# %%
# Level 19: TODO
def has_enough_level(player):
    ...

def has_magic_key(player):
    ...

def has_full_health(player):
    ...

def check_quest_access(player, *rules):
    ...


quest_player = {
    'level': 12, 'inventory': ['potion', 'map'],
    'hp': 80, 'max_hp': 100
}

failed = check_quest_access(
    quest_player, has_enough_level, has_magic_key, has_full_health
)
print('Failed rules:', failed)

# %% [markdown]
# ## Level 20: Mini RPG Turn Engine
#
# สร้าง `attack`, `heal` และ `charge_mana` ให้รับ hero กับ value และคืนสถานะใหม่โดยไม่แก้ dictionary ต้นฉบับ
#
# จากนั้นสร้าง `execute_turn(hero, action, value)` เพื่อเรียก action ที่รับเข้ามา

# %%
# Level 20: TODO
def attack(hero, value):
    ...

def heal(hero, value):
    ...

def charge_mana(hero, value):
    ...

def execute_turn(hero, action, value):
    ...


hero = {'hp': 70, 'max_hp': 100, 'mana': 20, 'enemy_hp': 60}
hero = execute_turn(hero, attack, 25)
hero = execute_turn(hero, heal, 50)
hero = execute_turn(hero, charge_mana, 15)
print(hero)

# %% [markdown]
# ## Final Challenge: Adventure Booking System
#
# สร้างระบบจองทริปด้วยฟังก์ชัน:
#
# 1. `calculate_item_cost(*items)` รวมราคาอุปกรณ์
# 2. `calculate_trip_cost(days, daily_rate=500)` คำนวณค่าทริป
# 3. `create_booking(name, destination, *items, days=1, daily_rate=500, **options)` คืน dictionary สรุปการจองและค่าใช้จ่ายรวม

# %%
# Final Challenge: TODO
def calculate_item_cost(*items):
    ...

def calculate_trip_cost(days, daily_rate=500):
    ...

def create_booking(
    name, destination, *items, days=1, daily_rate=500, **options
):
    ...


booking = create_booking(
    'Mina', 'Crystal Mountain', 250, 120, 80,
    days=3, guide=True, meal='vegetarian'
)

print(booking)
