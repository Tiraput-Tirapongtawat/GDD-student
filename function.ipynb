# %% [markdown]
# # Function

# %% [markdown]
# โครงสร้าง functiion
# def name():
#     method
#     method
#
# การเรียกใช้งาน
#
# name()

# %%
def generate_name():
    print("test function")

# %%
generate_name()
# Out:
# test function

# %%
def generate_name():
    first_name = "Tiraput"
    last_name = "Tira."
    space = " "
    print(first_name + space + last_name)
    # print("test function")

# %%
generate_name()
# Out:
# Tiraput Tira.

# %% [markdown]
# # return

# %%
def generate_name():
    first_name = "Tiraput"
    last_name = "Tira."
    space = " "
    # print(first_name + space + last_name)
    return first_name + space + last_name

# %%
test = generate_name()
print(test)
# Out:
# Tiraput Tira.

# %%
def get_password():
    print("This is your password.")
    return "1234"

# %%
password = get_password()
# Out:
# This is your password.

# %%
print(password)
# Out:
# 1234

# %%
if password == "1235":
    print("Incomplete login")

# %% [markdown]
# parameter
# def function_name(parameter):
#     method
#     method
# วิธีการเรียกใช้งาน
# function_mame(parameter)

# %%
def greeting(name):
    message = name + ", Welcome to GDD coding"
    return message

test_function = greeting("Pun")

# %%
print(test_function)
# Out:
# Pun, Welcome to GDD coding

# %%
def greeting(nickname, FirstName , LastName ):
    message = nickname+ " "+ FirstName + " "+ LastName + ", Welcome to GDD coding"
    return message

# %%
test_function = greeting("Can", "Tiraput", "Tira")

# %%
print(test_function)
# Out:
# Can Tiraput Tira, Welcome to GDD coding

# %% [markdown]
# โจทย์
# สร้าง function
#
# 1. บวกเลข ใส่เลขไป 2 ตัว ให้  return ผลรวม
# 2. คูณเลข ใส่เลขไป 2 ตัว ให้  return ผลคูณ
# 3. ใส่เลขไป 1 ตัว (1. รัศมี) ให้  return พื้นวงกลม (PI * r ** 2)

# %%
def plus(num1,num2):
    result = num1 + num2
    return result

test_function = plus(10,20)
print(test_function)
# Out:
# 30

# %%
def multiply(first_num,second_num):
    return first_num*second_num

# %%
test = multiply(10,6)
print(test)
# Out:
# 60

# %%
def area_circle(radius):
    pi = 3.14*radius**2
    return pi

# %%
test_function = area_circle(2)

# %%
print(test_function)
# Out:
# 12.56

# %%
def calculate_age(years = 2005): #default parameter
    # result = 2026 - years
    return 2026 - years

# %%
test_function = calculate_age()

# %%
print(test_function)
# Out:
# 21

# %%
def add_friend(user, friends):
    return user + " have new friends : " + friends

# %%
test_friend = add_friend(user="Akin", friends="Thank")

# %%
print(test_friend)
# Out:
# Akin have new friends : Thank

# %%
def add_friends(user, *args):
    return user + f" have new friends :  {args}"

# %%
test_friend = add_friends("Akin", "U", "Pun","Thank","Can","New")

# %%
print(test_friend)
# Out:
# Akin have new friends :  ('U', 'Pun', 'Thank', 'Can', 'New')

# %%
food_stuff = ["Potato", "Tomato", "Mango", "Milk"]
# function add items parameter (food_stuff , new_item) -> output :  ["Potato", "Tomato", "Mango", "Milk", "Water"]

# %%
a = [1,3,5,5,2,4,3,2]
b = 0

a.append(b)
print(a)
# Out:
# [1, 3, 5, 5, 2, 4, 3, 2, 0]

# %%
def food_stuffs(stuff, new_item):
   stuff.append(new_item)
   return stuff

# %%
test_function = food_stuffs(food_stuff,"Water")

# %%
print(test_function)
# Out:
# ['Potato', 'Tomato', 'Mango', 'Milk', 'Water']
