# %% [markdown]
# # Day 8 - Creative Dictionary Exercises: Student Version
#
# ชุดโจทย์เสริมเรื่อง `dictionary` เรียงจากง่ายไปยาก สำหรับนักเรียน
#
# วิธีใช้:
#
# 1. อ่านโจทย์
# 2. เติม code ใน cell ที่มี `TODO`
# 3. แทนที่ `...` ด้วยคำตอบของตัวเอง
# 4. รัน cell เพื่อตรวจผลลัพธ์

# %% [markdown]
# ## Level 1: Name Tag Generator
#
# สร้าง dictionary ชื่อ `student` ที่เก็บข้อมูลนักเรียน 1 คน:
#
# - `name`
# - `nickname`
# - `age`
# - `city`
#
# จากนั้นให้แสดงข้อความแนะนำตัวในรูปแบบ:
#
# ```text
# Hello, my name is Mina. You can call me Min. I am 16 years old and I live in Bangkok.
# ```

# %%
# Level 1: TODO
student = {
    'name': "Timmy",
    'nickname': "Tim",
    'age': "9",
    'city': "Bangkok"
}

message = f"Hello, ..... is {student['name']} You can me {student['nickname']}"
print(message)
# Out:
# Hello, ..... is Timmy You can me Tim

# %%
a = 10

b = "5 + 5 = " + str(a)
c = f"5 + 5 = {a}"
print(b)
print(c)
# Out:
# 5 + 5 = 10
# 5 + 5 = 10

# %% [markdown]
# ## Level 2: Secret Character Profile
#
# สร้าง dictionary ชื่อ `character` เพื่อเก็บข้อมูลตัวละคร:
#
# - `name`
# - `role`
# - `level`
# - `hp`
#
# ให้เพิ่ม key ใหม่ชื่อ `mana` และแก้ไข `level` ให้เพิ่มขึ้น 1 ระดับ

# %%
# Level 2: TODO
character = {
    'name': "Stephen",
    'role': "NBA_player",
    'level': 40,
    'hp': 299
}

# TODO: add mana
character["mana"] = 10000

# TODO: increase level by 1
character["level"] = character["level"] + 1
character["level"] +=  1

print(character)
# Out:
# {'name': 'Stephen', 'role': 'NBA_player', 'level': 42, 'hp': 299, 'mana': 10000}

# %% [markdown]
# ## Level 3: Cafe Menu
#
# กำหนด dictionary ชื่อ `menu` ที่เก็บชื่อเครื่องดื่มและราคา
#
# ให้ทำงานต่อไปนี้:
#
# 1. แสดงราคาของ `latte`
# 2. เพิ่มเมนูใหม่ `matcha` ราคา 65
# 3. แก้ราคา `espresso` เป็น 45
# 4. ลบเมนู `tea`
# 5. แสดงเมนูทั้งหมด

# %%
# Level 3: TODO
menu = {
    'espresso': 40,
    'latte': 55,
    'cappuccino': 60,
    'tea': 35
}

# TODO 1: show latte price
print('Latte price : ', menu["latte"])

# TODO 2: add matcha price 65
menu["matcha"] = 65

# TODO 3: change espresso price to 45
menu["espresso"] = 45

# TODO 4: remove tea
menu.pop("tea")

# TODO 5: show all menu items
# print(menu)
for beverage, price in menu.items():
    print(f" Menu : {beverage} , Price : {price}")
# Out:
# Latte price :  55
#  Menu : espresso , Price : 45
#  Menu : latte , Price : 55
#  Menu : cappuccino , Price : 60
#  Menu : matcha , Price : 65

# %% [markdown]
# ## Level 4: Backpack Inventory
#
# สร้าง dictionary ชื่อ `backpack` เพื่อเก็บสิ่งของและจำนวน เช่น:
#
# ```python
# backpack = {
#     'potion': 3,
#     'coin': 20,
#     'key': 1
# }
# ```
#
# ให้เขียนโค้ด:
#
# 1. เพิ่ม `coin` อีก 10 เหรียญ
# 2. ใช้ `potion` ไป 1 ขวด
# 3. ถ้า `map` ไม่มีในกระเป๋า ให้เพิ่ม `map` จำนวน 1
# 4. แสดงของทั้งหมดในกระเป๋า

# %%
# Level 4: TODO
backpack = {
    'potion': 3,
    'coin': 20,
    'key': 1
}

# TODO 1: add 10 coins
backpack['coin'] += 10

# TODO 2: use 1 potion
backpack['potion'] -= 1
...

# TODO 3: add map if it does not exist
if "map" not in backpack:
    backpack["map"] = 1    

# TODO 4: show all items

for item, amount in backpack.items():
    print(f" Item : {item},  Amount : {amount}")
# Out:
#  Item : potion,  Amount : 2
#  Item : coin,  Amount : 30
#  Item : key,  Amount : 1
#  Item : map,  Amount : 1

# %% [markdown]
# ## Level 5: Grade Translator
#
# กำหนด dictionary ชื่อ `scores` ที่เก็บชื่อและคะแนนนักเรียน
#
# ให้สร้าง dictionary ใหม่ชื่อ `grades` โดยใช้เงื่อนไข:
#
# - 90 ขึ้นไป = `A`
# - 80-89 = `B`
# - 70-79 = `C`
# - 60-69 = `D`
# - ต่ำกว่า 60 = `F`

# %%
# Level 5: TODO
scores = {
    'Anna': 92,
    'Ben': 76,
    'Cara': 84,
    'Dan': 59,
    'Eli': 68
}

grades = {}

# TODO: fill grades dictionary using if / elif / else
for name, score in scores.items():
    if score > 90:
        grades[name] = "A"
    elif score >= 80:
        grades[name] = "B"
    elif score >= 70:
        grades[name] = "C"
    elif score >= 60:
        grades[name] = "D"
    else:
        grades[name] = "F"

# print(grades)

for name , grade in grades.items():
    print(f" Name : {name} , Grade : {grade}")


# scores = {"Anna": "A", "Ben": "C", "Cara": 84, "Dan": 59, "Eli": 68}
# Out:
#  Name : Anna , Grade : A
#  Name : Ben , Grade : C
#  Name : Cara , Grade : B
#  Name : Dan , Grade : F
#  Name : Eli , Grade : D

# %% [markdown]
# ## Level 6: Emoji Mood Counter
#
# กำหนด list ของ mood ในแต่ละวัน
#
# ```python
# moods = ['happy', 'sad', 'happy', 'excited', 'happy', 'sad']
# ```
#
# ให้สร้าง dictionary ชื่อ `mood_count` เพื่อนับว่าแต่ละ mood เกิดกี่ครั้ง

# %%
# Level 6: TODO
moods = ['happy', 'sad', 'happy', 'excited', 'happy', 'sad']

mood_count = {}
# mood_count = {"happy":3, "sad":2, "excited": 1}

# TODO: count each mood
for mood in moods:
    print(mood)
    if mood in mood_count:
        mood_count[mood] += 1
    else:
        mood_count[mood] = 1
    

print(mood_count)
# Out:
# happy
# sad
# happy
# excited
# happy
# sad
# {'happy': 3, 'sad': 2, 'excited': 1}

# %% [markdown]
# ## Level 7: Mini Library System
#
# สร้าง nested dictionary ชื่อ `library`
#
# แต่ละ book id ต้องเก็บ:
#
# - `title`
# - `author`
# - `available`
#
# ให้เขียนโค้ด:
#
# 1. แสดงรายชื่อหนังสือทั้งหมด
# 2. แสดงเฉพาะหนังสือที่ยังว่างให้ยืม
# 3. เปลี่ยนสถานะหนังสือ `book_1` เป็นไม่ว่าง

# %%
# Level 7: TODO
library = {
    'book_1': {
        'title': 'Python Basics',
        'author': 'Nina Code',
        'available': True
    },
    'book_2': {
        'title': 'Data Stories',
        'author': 'Leo Graph',
        'available': False
    },
    'book_3': {
        'title': 'Web Starter',
        'author': 'Maya HTML',
        'available': True
    }
}

# TODO 1: show all book titles
# for book , info in library.items():
    # print(f"Book :  {info['title']}")

# TODO 2: show only available books
for book, info in library.items():
    # print(book , info)
    # print(info['available'])
    if info['available']:
        print(info['title'])

# TODO 3: change book_1 available status to False
library['book_1']['available'] = False

print(library['book_1'])
# Out:
# Python Basics
# Web Starter
# {'title': 'Python Basics', 'author': 'Nina Code', 'available': False}

# %%
print(library['book_1'])
# Out:
# {'title': 'Python Basics', 'author': 'Nina Code', 'available': True}

# %% [markdown]
# ## Level 8: Restaurant Receipt
#
# กำหนด dictionary ราคาสินค้า `prices` และจำนวนที่ลูกค้าสั่ง `order`
#
# ให้คำนวณราคารวมและแสดงใบเสร็จ
#
# ```text
# burger x 2 = 160
# fries x 1 = 45
# water x 3 = 30
# Total = 235
# ```

# %%
# Level 8: TODO
prices = {
    'burger': 80,
    'fries': 45,
    'water': 10,
    'salad': 65
}

order = {
    'burger': 2,
    'fries': 1,
    'water': 3
}

total = 0

# TODO: print receipt and calculate total
for item, quantity in order.items():
    # print(quantity)
    # print(item)
    price = quantity * prices[item]
    total = total + price

print(f'Total = {total}')
# Out:
# Total = 235

# %%
# prices = {"burger": 80, "fries": 45, "water": 10, "salad": 65}
# prices['burger']

example = 10

example = example + 10
example += 10
# Out:
# 80

# %% [markdown]
# ## Level 9: Word Frequency Detective
#
# กำหนดประโยค:
#
# ```python
# sentence = 'python is fun and python is useful and dictionary is powerful'
# ```
#
# ให้เขียนโค้ด:
#
# 1. แยกคำด้วย `.split()`
# 2. นับจำนวนคำแต่ละคำด้วย dictionary
# 3. หาคำที่พบมากที่สุด

# %%
example = "asdihflakd. asdfioaksdf sdhfklandkn asdojfasdfn"
print(example.split())
# Out:
# ['asdihflakd.', 'asdfioaksdf', 'sdhfklandkn', 'asdojfasdfn']

# %%
# Level 9: TODO
sentence = 'python is fun and python is useful and dictionary is powerful'
words = sentence.split()
print(words)
word_count = {}

# TODO 1: count each word
for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

most_common_word = None
highest_count = 0

# TODO 2: find the most common word
for word, count in word_count.items():
    if count  > highest_count:
        most_common_word = word
        highest_count = count
print('Word count:', word_count)
print('Most common word:', most_common_word)
print('Count:', highest_count)
# Out:
# ['python', 'is', 'fun', 'and', 'python', 'is', 'useful', 'and', 'dictionary', 'is', 'powerful']
# Word count: {'python': 2, 'is': 3, 'fun': 1, 'and': 2, 'useful': 1, 'dictionary': 1, 'powerful': 1}
# Most common word: is
# Count: 3

# %% [markdown]
# ## Level 10: Game Shop Recommendation
#
# กำหนด dictionary ชื่อ `games` ที่เก็บข้อมูลเกมแต่ละเกม:
#
# - `price`
# - `genre`
# - `rating`
#
# ให้หาเกมที่:
#
# 1. ราคาไม่เกิน 500
# 2. rating ตั้งแต่ 8.5 ขึ้นไป
#
# แล้วเก็บชื่อเกมที่ผ่านเงื่อนไขไว้ใน list ชื่อ `recommended_games`

# %%
# Level 10: TODO
games = {
    'Sky Quest': {
        'price': 450,
        'genre': 'Adventure',
        'rating': 8.7
    },
    'Battle Core': {
        'price': 799,
        'genre': 'Action',
        'rating': 9.0
    },
    'Pixel Farm': {
        'price': 299,
        'genre': 'Simulation',
        'rating': 8.2
    },
    'Code Dungeon': {
        'price': 499,
        'genre': 'Puzzle',
        'rating': 8.9
    }
}

recommended_games = []

# TODO: add game title if price <= 500 and rating >= 8.5
for title, info in games.items():
    if info['price'] <=500 and info["rating"] >= 8.5:
        recommended_games.append(title)

print('Recommended games:', recommended_games)

# Recommended games: ['Sky Quest', 'Code Dungeon']
# Out:
# Recommended games: ['Sky Quest', 'Code Dungeon']

# %%
example = []
example.append("apple")
print(example)
# Out:
# ['apple']

# %% [markdown]
# ## Level 11: Classroom Attendance Tracker
#
# กำหนด dictionary ชื่อ `attendance` ที่เก็บชื่อนักเรียนและสถานะการมาเรียน
#
# ให้เขียนโค้ด:
#
# 1. นับจำนวนนักเรียนที่มาเรียน (`present`)
# 2. นับจำนวนนักเรียนที่ขาดเรียน (`absent`)
# 3. สร้าง list ชื่อ `absent_students` เก็บชื่อคนที่ขาดเรียน
# 4. เปลี่ยนสถานะของ `Nora` เป็น `present`

# %%
# Level 11: TODO
attendance = {
    'Mina': 'present',
    'Leo': 'absent',
    'Nora': 'absent',
    'Kai': 'present',
    'June': 'present'
}

present_count = 0
absent_count = 0
absent_students = []

# TODO 1-3: count present, count absent, and collect absent students
for name, status in attendance.items():
    ...

# TODO 4: change Nora status to present
...

print('Present:', present_count)
print('Absent:', absent_count)
print('Absent students:', absent_students)
print('Updated attendance:', attendance)

# %% [markdown]
# ## Level 12: Product Stock Manager
#
# กำหนด dictionary ชื่อ `stock` ที่เก็บจำนวนสินค้าในคลัง
#
# ให้เขียนโค้ด:
#
# 1. เพิ่มสินค้าใหม่ `notebook` จำนวน 12
# 2. ขาย `pen` ออกไป 5 ชิ้น
# 3. เติม `eraser` เข้าไปอีก 10 ชิ้น
# 4. แสดงเฉพาะสินค้าที่มีจำนวนน้อยกว่า 10 ชิ้น

# %%
# Level 12: TODO
stock = {
    'pen': 20,
    'pencil': 8,
    'eraser': 5,
    'ruler': 15
}

# TODO 1: add notebook = 12
...

# TODO 2: sell 5 pens
...

# TODO 3: add 10 erasers
...

low_stock = {}

# TODO 4: keep only products with amount less than 10
for product, amount in stock.items():
    ...

print('Stock:', stock)
print('Low stock:', low_stock)

# %% [markdown]
# ## Level 13: Travel Planner
#
# สร้าง nested dictionary ชื่อ `trip` ที่เก็บข้อมูลเมืองและค่าใช้จ่ายแต่ละหมวด
#
# ให้เขียนโค้ด:
#
# 1. คำนวณค่าใช้จ่ายรวมของแต่ละเมือง
# 2. หาเมืองที่ค่าใช้จ่ายถูกที่สุด
# 3. หาเมืองที่ค่าใช้จ่ายแพงที่สุด

# %%
# Level 13: TODO
trip = {
    'Chiang Mai': {
        'hotel': 1800,
        'food': 900,
        'transport': 700
    },
    'Phuket': {
        'hotel': 3200,
        'food': 1400,
        'transport': 1200
    },
    'Ayutthaya': {
        'hotel': 1200,
        'food': 600,
        'transport': 400
    }
}

total_costs = {}

# TODO 1: calculate total cost for each city
for city, costs in trip.items():
    ...

# TODO 2-3: find cheapest and most expensive city
cheapest_city = ...
most_expensive_city = ...

print('Total costs:', total_costs)
print('Cheapest city:', cheapest_city)
print('Most expensive city:', most_expensive_city)

# %% [markdown]
# ## Level 14: Social Media Hashtag Counter
#
# กำหนด list ของ post แต่ละ post มี hashtag หลายคำ
#
# ให้เขียนโค้ด:
#
# 1. นับจำนวนครั้งที่ hashtag แต่ละตัวถูกใช้
# 2. หา hashtag ที่ถูกใช้มากที่สุด
# 3. สร้าง list ของ hashtag ที่ถูกใช้ตั้งแต่ 2 ครั้งขึ้นไป

# %%
# Level 14: TODO
posts = [
    ['python', 'coding', 'beginner'],
    ['python', 'dictionary', 'coding'],
    ['ai', 'python', 'learning'],
    ['coding', 'project', 'dictionary']
]

hashtag_count = {}

# TODO 1: count each hashtag
for post in posts:
    for hashtag in post:
        ...

# TODO 2: find the most used hashtag
most_used = ...

popular_hashtags = []

# TODO 3: collect hashtags used at least 2 times
for hashtag, count in hashtag_count.items():
    ...

print('Hashtag count:', hashtag_count)
print('Most used hashtag:', most_used)
print('Popular hashtags:', popular_hashtags)

# %% [markdown]
# ## Level 15: Dictionary Data Cleaning
#
# กำหนด dictionary ชื่อ `profile` ที่มีข้อมูลบาง field เป็นค่าว่างหรือ `None`
#
# ให้เขียนโค้ด:
#
# 1. ลบ key ที่มีค่าเป็น `None` หรือ string ว่าง `""`
# 2. สร้าง dictionary ใหม่ชื่อ `clean_profile`
# 3. เพิ่ม key `is_complete` เป็น `True` ถ้าไม่มี field ว่างเหลืออยู่

# %%
# Level 15: TODO
profile = {
    'name': 'Mina',
    'email': 'mina@example.com',
    'phone': '',
    'city': 'Bangkok',
    'school': None,
    'skill': 'Python'
}

clean_profile = {}

# TODO 1-2: copy only fields that are not None and not empty string
for key, value in profile.items():
    ...

# TODO 3: add is_complete
clean_profile['is_complete'] = ...

print('Original profile:', profile)
print('Clean profile:', clean_profile)

# %% [markdown]
# ## Final Challenge: Contact Book
#
# สร้างระบบ contact book ด้วย dictionary
#
# ข้อมูล contact แต่ละคนควรมี:
#
# - `phone`
# - `email`
# - `city`
#
# ให้เขียน function ต่อไปนี้:
#
# 1. `add_contact(name, phone, email, city)`
# 2. `find_contact(name)`
# 3. `update_phone(name, new_phone)`
# 4. `delete_contact(name)`
# 5. `show_all_contacts()`

# %%
# Final Challenge: TODO
contacts = {}


def add_contact(name, phone, email, city):
    # TODO: add contact data into contacts
    ...


def find_contact(name):
    # TODO: return contact data or 'Contact not found'
    ...


def update_phone(name, new_phone):
    # TODO: update phone if contact exists
    ...


def delete_contact(name):
    # TODO: delete contact if contact exists
    ...


def show_all_contacts():
    # TODO: print all contacts
    ...


# Test your functions here
add_contact('Mina', '081-111-1111', 'mina@example.com', 'Bangkok')
add_contact('Leo', '082-222-2222', 'leo@example.com', 'Chiang Mai')

print(find_contact('Mina'))
print(update_phone('Mina', '089-999-9999'))
print(delete_contact('Leo'))
show_all_contacts()
