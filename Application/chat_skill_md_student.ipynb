# %% [markdown]
# # ใบงานนักเรียน: เขียน Local Chatbot ด้วยตัวเอง 🤖
#
# ชื่อ ____________________ ชั้น ______ เลขที่ ______
#
# กติกา:
#
# - อ่านโจทย์แล้ว **พิมพ์โค้ดเอง** ในเซลล์ `TODO`
# - รันทีละเซลล์จากบนลงล่าง
# - หากผ่าน Checkpoint แล้วจึงไปขั้นถัดไป
# - ไม่ใช้ Gradio ในบทเรียนนี้

# %% [markdown]
# ## เป้าหมาย
#
# เมื่อจบบทเรียน นักเรียนจะสามารถ:
#
# 1. เชื่อม Python กับ Ollama
# 2. ส่งคำถามและรับคำตอบจากโมเดล
# 3. เขียนฟังก์ชัน `ask_bot()` และ `chat()`
# 4. ทำให้ Chatbot จำบทสนทนา
# 5. ให้ Chatbot ช่วยสร้าง `SKILL.md`

# %% [markdown]
# ## 1) ติดตั้งไลบรารี
#
# พิมพ์คำสั่ง `%pip install -qU openai` ในเซลล์ด้านล่าง แล้วรันหนึ่งครั้ง

# %%
# TODO: พิมพ์คำสั่งติดตั้ง openai

irm https://ollama.com/install.ps1 | iex

ollama --version

# %% [markdown]
# ## 2) ตั้งค่าการเชื่อมต่อ
#
# พิมพ์โค้ดเพื่อ:
#
# 1. import `OpenAI` จาก `openai`
# 2. กำหนด `MODEL` เป็น `qwen3.5:4b`
# 3. กำหนด `OLLAMA_HOST` เป็น `http://127.0.0.1:11434`
# 4. สร้าง `OPENAI_COMPAT_BASE` โดยเติม `/v1/`
#
# ผลที่ควรได้:
#
# ```text
# http://127.0.0.1:11434/v1/
# ```

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (2.46.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from openai) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/tiraputtirapongtawat/miniconda3/envs/gdd/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %%
# TODO: import OpenAI และสร้างตัวแปร MODEL, OLLAMA_HOST, OPENAI_COMPAT_BASE แล้ว print URL
from openai import OpenAI

# %% [markdown]
# ## 3) สร้าง client
#
# สร้างตัวแปร `client` ด้วย `OpenAI(...)`
#
# คำใบ้:
#
# - `base_url` ใช้ค่าจาก `OPENAI_COMPAT_BASE`
# - `api_key` ใช้ข้อความ `ollama`

# %%
# TODO: สร้าง client สำหรับเชื่อมต่อ Ollama
from openai import OpenAI

MODEL = "qwen3.5:4b"
OLLAMA_HOST = "http://127.0.0.1:11434"
OPENAI_COMPAT_BASE = f"{OLLAMA_HOST}/v1/"

client = OpenAI(
    base_url=OPENAI_COMPAT_BASE,
    api_key = "ollama",
    
)

# %% [markdown]
# ## 4) Chatbot ตัวแรก — ยังไม่ใช้ function
#
# เรียก `client.chat.completions.create(...)` โดยกำหนด:
#
# - `model=MODEL`
# - system: `คุณเป็นผู้ช่วยสอนที่เป็นมิตร ตอบไม่เกิน 2 ประโยค`
# - user: `Chatbot คืออะไร`
# - `reasoning_effort="none"`
# - `max_tokens=120`
#
# เก็บผลไว้ในตัวแปร `response` แล้ว print คำตอบจาก:
#
# ```text
# response.choices[0].message.content
# ```

# %%
# TODO: ส่งคำถามแรกให้โมเดลและ print คำตอบ

respond = client.chat.completions.create(
    model= MODEL,
    messages=[
        {"role":"system", "content":"คุณเป็นผู้ช่วยที่เป็นมิตร และตอบคำถามทุกอย่างได้อย่างแม่นยำ"},
        {"role":"user", "content":"แนะนำวิธีการเรียน python ที่มีประสิทธิภาพ"},
    ],
    reasoning_effort="none",
    max_tokens=500
)

# %%
print("Chat with LLM : ", respond.choices[0].message.content)
# Out:
# Chat with LLM :  สวัสดีครับ! ฉันยินดีเป็นอย่างยิ่งที่จะเป็น رفيق (ผู้ร่วมเดินทาง) ในกระบวนการเรียนรู้ Python ของคุณ 🐍 เรียนรู้ภาษาเขียนโปรแกรมที่ทรงพลังและมีความนิยมสูงนี้ สามารถทำสิ่งใดก็ได้ตั้งแต่ควบคุมระบบจนถึงสร้างปัญญาประดิษฐ์ ได้เลยครับ
#
# เพื่อให้การเรียนรู้ของคุณ"**มีประสิทธิภาพสูงสุด**" ผมขอแนะนำแนวทางแบบ **"Active Learning"** (การเรียนผ่านการลงมือปฏิบัติจริงๆ) แทนการอ่านทฤษฎีอย่างเดียว แบ่งออกเป็น 4 ขั้นตอนหลักดังนี้ครับ:
#
# ### 1. กำหนดเป้าหมายที่ชัดเจน (Set a Goal)
# อย่าเริ่มด้วย "เรียนรู้ Python ทั้งหมด" เพราะจะทำให้รู้สึกหมดไฟ ลองตั้งโจทย์เล็กๆ ที่ทำให้เห็นประโยชน์ทันที เช่น:
# *   *อยากทำงานกับข้อมูล?* -> เป้าหมาย: Pandas & NumPy
# *   *อยากรับจ้างทำเว็บแอปพื้นฐาน?* -> เป้าหมาย: Flask หรือ FastAPI + HTML/CSS
# *   *อยากสร้าง Chatbot?* -> เปาหมาย: NLP (การประมวลผลภาษาธรรมชาติ)
# *   **เคล็ดลับ:** การมีเป้าหมายชัดเจนจะทำให้คุณเลือกอ่านเพียงบทที่ต้องการจริง และโฟกัสเรื่องนั้นได้
#
# ### 2. สร้างสภาพแวดล้อมการเรียนรู้ที่ถูกต้อง (Environment Setup)
# ก่อนเขียนโค้ด ให้ใช้เครื่องมือที่ได้มาตรฐานเพื่อลดความผิดพลาดที่ไม่จำเป็น:
# *   ใช้ **Python** เวอร์ชันล่าสุด (3.x ไม่ใช่ 2.x แล้ว) ติดตั้งได้จาก `python.org` หรือผ่าน Anaconda/Miniconda สำหรับจัดการไลบรารีได้ง่าย
# *   ต้องมี Editor ของตัวเอง แนะนำให้ใช้โปรแกรมที่ทันสมัยและรองรับ Python ดีที่สุดสองตัว คือ:
#     *   **VS Code** (นิยมมาก, มี Plugin รองรับหลายภาษาได้)
#     *   **PyCharm Community Edition** (เหมาะสำหรับนักพัฒนามืออาชีพ มีเครื่องมือวิเคราะห์โค้ด Built-in)
#
# ### 3. สัมประสิทธิ์อัตราส่วนการเรียนรู้: ทฤษฎี : การปฏิบัติ = 1 : 5
# นี่คือหัวใจสำคัญที่สุด! อ่านเอกสาร หรือดูวิดีโอแค่อย่างเดียวถือว่าช้าไป เพราะสมองต้องประมวลผลและจำผ่าน "การเขียน" ครับ
# *   **แบบฝึกหัดตามหน้าหนังสือ:** อย่าข้ามเลย แม้จะเข้าใจแล้ว ให้ลองพิมพ์เองเพื่อตรวจสอบว่าเครื่องอ่านถูกต้องหรือไม่ (Syntax Error ก็เป็นวิชาเรียนที่ดีเหมือนกัน)
# *   **"Code Along":** หาโปรเจกต์ตัวอย่างขนาดเล็ก แล้วพยายามรันโค้ดนั้นให้ได้ก่อน ลองปรับแก้เล็กน้อยดู会发生อะไรขึ้น และสุดท้ายคือพยายามคิดเอง

# %% [markdown]
# ### Checkpoint 1
#
# หากเห็นข้อความหลัง `Bot:` แปลว่าเชื่อมต่อสำเร็จ ✅
#
# ตอบคำถาม:
#
# 1. `system` มีหน้าที่อะไร?
# 2. `user` มีหน้าที่อะไร?
# 3. `max_tokens` ช่วยเรื่องใด?

# %% [markdown]
# ## 5) เขียนฟังก์ชัน `ask_bot()`
#
# สร้างฟังก์ชันที่:
#
# 1. รับ parameter ชื่อ `question`
# 2. ส่ง `question` ให้โมเดล
# 3. เก็บคำตอบในตัวแปร `answer`
# 4. `return answer`
#
# คำใบ้: นำโค้ดจากขั้นที่ 4 มาปรับ ไม่ต้องเริ่มใหม่ทั้งหมด

# %%
# TODO: เขียน def ask_bot(question) ให้สมบูรณ์

# TODO: ส่งคำถามแรกให้โมเดลและ print คำตอบ
def ask_bot(question):
    respond = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": "คุณเป็นผู้ช่วยที่เป็นมิตร และตอบคำถามทุกอย่างได้อย่างแม่นยำ"},
            {"role": "user", "content": question},



        ],
        reasoning_effort="none",
        max_tokens=500,
    )
    answer = respond.choices[0].message.content
    return answer

# %%
ask_something  = ask_bot("วันนี้ตอนเช้า แดดร้อนมาก กินอะไรดี")
print(ask_something)
# Out:
# สวัสดีค่ะ! เข้าใจเลยว่าวันนี้อากาศช่างอบอ้าวจนทรมานจริงๆ 😫 การที่แดดแรงและอากาศร้อนมากๆ ร่างกายจะมีการสูญเสียน้ำและความเย็นไปไวๆ ถ้ากินอาหารไม่ถูกทาง อาจทำให้รู้สึกอ่อนเพลีย คลาดไส้ และเสียสมดุลได้ค่ะ
#
# เพื่อที่จะเติมพลังให้ร่างกายได้ดีที่สุดในวันนี้นะคะ แนะนำให้อาหารที่มี **"ความสดใหม่ สดชื่น หวานธรรมชาติ มีน้ำสูง"** เป็นหลัก โดยสามารถแบ่งเป็นกลุ่มดังนี้ค่ะ:
#
# ### 1. ผลไม้ที่แนะนำ (หวานเย็น ช่วยคลายความร้อน)
# ลูกห้อมๆ เหล่านี้มีความสดและฉ่ำน้ำ ช่วยให้เหงื่อไหลสะดวกขึ้นโดยที่คุณไม่ต้องพยายามฝืนกินผลไม้รสจัดร้อนๆ นะคะ 🍊🥭
# *   **ฝรั่งเขียว:** รสจืดอ่อนๆ ดิบนิดหน่อย แต่มีวิตามินสูงมาก และช่วยขับลมได้ (ควรเลือกที่พอจะเคี้ยวได้เลยแต่ไม่แข็งจนเกินไป)
# *   **ส้มโอ หรือ สับปะรดสด:** น้ำเยอะ ช่วยล้างพิษในร่างกายได้ดี
# *   **ขสมอ หวานน้อยเนื้อมันเล็กน้อย** (หากต้องการพลังงานเร็วๆ ในบางสถานการณ์ แต่สำหรับวันนี้แนะนำแบบหวานนิดหน่อยก็ไหว แต่ถ้าร้อนจัดจริงอาจต้องเลี่ยงเฉพาะที่รสหนักเกินไป)
#
# ### 2.อาหารหลักที่ย่อยง่าย ไม่ทำให้ท้องอืดหรือความร้อนขึ้นมาก
# *   **ข้าวกล้อง:** ดีกว่าข้าวขาว เพราะกากใยช่วยให้อิ่มนานและวิตามินดีต่อระบบย่อยอาหาร แต่ควรกินแบบไม่แข็งจนเคี้ยวยาก
# *   **ขนมปังโฮลวีต:** ย่อยได้ดี และไม่มีของหนักปนอยู่ด้วย
# *   **เต้าหู้, ไข่ต้ม, หรืออกไก่ปรุงรสต่ำ:** เป็นโปรตีนที่ร่างกายนำไปใช้ได้ง่าย และไม่ทำให้เกิดความร้อนในช่องท้องเหมือนเนื้อสัตว์บางชนิด
#
# ### 3.เครื่องดื่มที่เหมาะสม (ความชื้นสำคัญมาก!) 🥤💧
# *   **น้ำธรรมดา + เติมเกลือเล็กน้อย :** สำคัญที่สุด! เพราะเหงื่อจะพาแร่ธาตุออกไป การเติมsalt ช่วยให้นา้ซึมเข้าสู่กล้ามเนื้อได้ดีขึ้น
# *   **นมสด:** ถ้าไม่แพ้นม เป็นโปรตีน+แคลเซียมที่ดี ดื่มอุณหภูมิห้องหรือเย็นๆ ก็ใช้ได้ แต่อย่าดื่มตอนอากาศร้อนจัดเกินไปเพราะอาจทำให้ท้องอืดได้ (แต่ถ้าหิวน้ำมากจริงๆ สามารถดื่มนะคะ)
# *

# %% [markdown]
# ## 6) ทดลองเรียกฟังก์ชัน
#
# เรียก `ask_bot()` ด้วยคำถาม:
#
# ```text
# ฟังก์ชัน Python คืออะไร อธิบายใน 2 ข้อ
# ```
#
# แล้ว print คำตอบ

# %%
# TODO: เรียก ask_bot() และแสดงคำตอบ
example = ask_bot("รู้จัก GDD coding academy มั้ย")
print(example)
# Out:
# สวัสดีครับ! ผมได้ข้อมูลเกี่ยวกับ **GDD Coding Academy** (กลุ่มบริษัท หรือสถาบันเทคโนโลยีที่เน้นการสอนด้านโค้ดดิ้งและนวัตกรรม) ครับ
#
# โดยปกติแล้ว **GDD** มักจะหมายถึงบริษัทยักษ์ใหญ่ระดับโลกอย่าง **Google** เมื่อมาผสมกับคำว่า "Coding Academy" ในประเทศไทย อาจจะเป็นหน่วยงานเฉพาะหรือโครงการพิเศษภายใต้เครือ Google เช่น:
# 1.  **โปรแกรมเรียนฟรี (Free Training):** Google มีโครงการสอนโค้ดดิ้งพื้นฐานและเครื่องมือต่างๆ ให้ประชาชนทั่วไปผ่านแพลตฟอร์มเช่น **Code Newbies** หรือร่วมมือกับสถาบันการศึกษาที่ผ่านการรับรอง โดยมักจะมีเนื้อหาครอบคลุมภาษา Python, JavaScript และทักษะการทำงานในทีมพัฒนาซอฟต์แวร์
# 2.  **บริบทในประเทศไทย:** หากหมายถึงองค์กรเฉพาะทางที่ตั้งขึ้นมาเพื่อให้ความรู้ด้านดิจิทัล (Digital Literacy) สำหรับคนไทย บางครั้งก็อาจมีการใช้ออกแบบชื่อลักษณะนี้เพื่อระบุถึงโครงการของ Google for Startups หรือความร่วมมือกับภาคการศึกษา
#
# **สิ่งที่ทำได้อาจรวมถึง:**
# *   แนะนำหลักสูตรการโค้ดดิ้งที่เป็นมิตรต่อผู้เริ่มต้นและคนทั่วไป
# *   แจกแนวทางสำหรับการพัฒนาทักษะซอฟต์แวร์ (Dev Tools, Debugging) และแนวความคิดในการเขียนโปรแกรม (Programming Concepts) เช่น การคิดแบบตรรกะและการแก้ปัญหา (Problem-Solving)
# *   อธิบายเครื่องมือพื้นฐานที่ใช้โดยนักพัฒนาในองค์กรสมัยใหม่
#
# หากคุณต้องการคำแนะนำเรื่องการเริ่มเรียนหรือหัวข้อเฉพาะเจาะจง บอกผมได้เลยนะครับ! 😊

# %% [markdown]
# ### Checkpoint 2
#
# ตรวจด้วยตนเอง:
#
# - [ ] ฟังก์ชันรับคำถามได้
# - [ ] ฟังก์ชันคืนค่าเป็นข้อความ
# - [ ] คำตอบไม่ว่าง
# - [ ] คำตอบไม่ยาวเกินไป

# %% [markdown]
# ## 7) สร้างความจำ
#
# สร้าง list ชื่อ `chat_history` และใส่ข้อความแรกเป็น `role="system"`
#
# กำหนดให้ Bot:
#
# - เป็นผู้ช่วยสอนสำหรับเด็ก ม.ปลาย
# - ตอบไม่เกิน 3 ประโยค
# - ถามทีละคำถาม

# %%
# TODO: สร้าง chat_history ที่มี system message หนึ่งรายการ

# %% [markdown]
# ## 8) เขียนฟังก์ชัน `chat()`
#
# สร้างฟังก์ชัน `chat(message)` ตามลำดับ:
#
# 1. append ข้อความของผู้ใช้ลง `chat_history`
# 2. ส่ง `chat_history` ทั้งหมดให้โมเดล
# 3. อ่านคำตอบเก็บใน `answer`
# 4. append คำตอบด้วย `role="assistant"`
# 5. return คำตอบ

# %%
# TODO: เขียน def chat(message) ให้จำบทสนทนาได้

# %% [markdown]
# ## 9) ทดสอบความจำทีละคำถาม
#
# คำถามแรก:
#
# ```text
# ฉันชื่อเมย์ และอยากสร้าง Skill ช่วยติวคำศัพท์
# ```

# %%
# TODO: เรียก chat() ด้วยคำถามแรกและ print คำตอบ

# %% [markdown]
# รอคำตอบแรกให้เสร็จ แล้วถาม:
#
# ```text
# ฉันชื่ออะไร และอยากสร้างอะไร
# ```

# %%
# TODO: เรียก chat() ด้วยคำถามที่สองและ print คำตอบ

# %% [markdown]
# ### Checkpoint 3
#
# ถ้า Bot ตอบว่า “เมย์” และ “Skill ช่วยติวคำศัพท์” แสดงว่าความจำทำงาน ✅

# %% [markdown]
# ## 10) Challenge: เขียน `clear_chat()`
#
# สร้างฟังก์ชันสำหรับล้างประวัติ โดย:
#
# 1. ใช้ `chat_history.clear()`
# 2. append system message กลับเข้าไป
# 3. print `ล้างประวัติแล้ว`

# %%
# TODO: เขียน def clear_chat() แล้วทดลองเรียกใช้

# %% [markdown]
# ## 11) รู้จัก `SKILL.md`
#
# `SKILL.md` คือคู่มือบอก AI ว่า Skill ทำอะไร ใช้เมื่อใด และทำงานอย่างไร
#
# ```markdown
# ---
# name: vocabulary-quiz
# description: Create vocabulary quizzes. Use when a student wants to review English words.
# ---
#
# # Vocabulary Quiz
#
# ## Workflow
#
# 1. Ask for a topic.
# 2. Create five questions.
# 3. Check and explain the answers.
# ```
#
# กติกาหลัก:
#
# - Frontmatter มีเพียง `name` และ `description`
# - `name` ใช้ตัวพิมพ์เล็ก ตัวเลข และขีดกลาง
# - `description` บอกทั้งสิ่งที่ทำและจังหวะที่ควรใช้
# - เนื้อหามีขั้นตอนที่ทำตามได้

# %% [markdown]
# ## 12) ให้ Chatbot สร้าง SKILL.md
#
# สร้างตัวแปร `skill_prompt` เพื่อสั่งให้ Bot:
#
# 1. สร้าง Skill เกมทายคำศัพท์
# 2. ใช้กติกาจากขั้นที่ 11
# 3. ตอบเฉพาะเนื้อหา `SKILL.md`
#
# จากนั้นส่ง `skill_prompt` เข้า `ask_bot()` และเก็บผลใน `skill_draft`

# %%
# TODO: สร้าง skill_prompt เรียก ask_bot() และ print skill_draft

# %% [markdown]
# ## 13) เขียนตัวตรวจแบบง่าย
#
# สร้างฟังก์ชัน `check_skill(skill_text)` ให้ตรวจว่าในข้อความมี:
#
# - `name:`
# - `description:`
# - `Use when`
# - `## Workflow`
#
# ให้แสดง ✅ เมื่อพบ และ ❌ เมื่อไม่พบ

# %%
# TODO: เขียน def check_skill(skill_text) และทดสอบกับ skill_draft

# %% [markdown]
# ## Mini Project 🚀
#
# เลือกหนึ่งหัวข้อ:
#
# - ผู้ช่วยวางแผนอ่านหนังสือ
# - เกมตอบคำถามวิทยาศาสตร์
# - ผู้ช่วยฝึกภาษาอังกฤษ
# - ผู้ช่วยสำรวจอาชีพ
# - ไอเดียของนักเรียนเอง
#
# งานที่ต้องส่ง:
#
# 1. Chatbot สนทนาและจำข้อมูลได้
# 2. มีฟังก์ชัน `ask_bot()`, `chat()`, `clear_chat()` และ `check_skill()`
# 3. สร้าง `SKILL.md` ตามหัวข้อของตัวเอง
# 4. ผลตรวจเป็น ✅ ครบทุกข้อ
# 5. อธิบายโค้ดของตัวเองให้เพื่อนฟังได้

# %% [markdown]
# ## สะท้อนการเรียนรู้
#
# 1. ส่วนใดยากที่สุด เพราะอะไร?
# 2. ฟังก์ชันช่วยลดโค้ดซ้ำอย่างไร?
# 3. `chat_history` ทำให้ Bot จำได้อย่างไร?
# 4. ข้อมูลใดไม่ควรส่งให้ Chatbot?
